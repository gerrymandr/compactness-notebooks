# %% [markdown]
# # Data Download

# %% [markdown]
# To download our data, we use Boto3 (AWS's Python API). Beyond that, we use pandas and numpy to manipulate data and use sqlite3/json to match up districts with responses. Finally we use sklearn for scaling and plotly for visualizations.

# %%
import boto3
import numpy as np
import pandas as pd
import sqlite3
import json

# %%
from sklearn.preprocessing import scale
from sklearn import svm

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# #### Get Credentials

# %% [markdown]
# Credentials should be stored in a text file with the secret followed by the id on a different line.

# %%
key_id = None
key_secret = None
with open('credentials', "r") as cred_file:
    key_secret = cred_file.readline().strip()
    key_id = cred_file.readline().strip()

# %% [markdown]
# #### Initialization

# %%
session = boto3.Session(aws_access_key_id = key_id, aws_secret_access_key = key_secret, region_name='us-east-2')
dynamodb = session.resource('dynamodb')
table = dynamodb.Table('GerrymandrResponses')

# %% [markdown]
# #### Download/Parse

# %% [markdown]
# We then download all data from the table using scan(). In the future we might have to split up reads because as we get more users the table will obviously grow in size. Responses come through as a JSON.

# %%
items = table.scan()['Items']

# %%
items
# Out:
# [{'14': {'fair': True,
#    'timeToDecide': Decimal('2.43115496635437'),
#    'timestamp': '4/15/18, 1:31:21 PM Pacific Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '202': {'fair': True,
#    'timeToDecide': Decimal('2.8891190290451'),
#    'timestamp': '4/15/18, 1:31:19 PM Pacific Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '287': {'fair': True,
#    'timeToDecide': Decimal('1.31926608085632'),
#    'timestamp': '4/15/18, 1:31:23 PM Pacific Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   'userID': 'us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea'},
#  {'106': {'fair': True,
#    'timeToDecide': Decimal('177.864262938499'),
#    'timestamp': '2/24/18, 8:15:03 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedRace': True},
#   '128': {'fair': True,
#    'timeToDecide': Decimal('262.761456012726'),
#    'timestamp': '3/1/18, 4:23:08 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedRace': True},
#   '13': {'fair': True,
#    'timeToDecide': Decimal('30.5825890302658'),
#    'timestamp': '4/5/18, 4:18:57 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': False,
#    'viewedRace': False},
#   '136': {'fair': True,
#    'timeToDecide': Decimal('1.38291203975677'),
#    'timestamp': '3/1/18, 4:17:44 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '138': {'fair': True,
#    'timeToDecide': Decimal('2.06638991832733'),
#    'timestamp': '3/1/18, 4:23:16 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '139': {'fair': True,
#    'timeToDecide': Decimal('2.10739898681641'),
#    'timestamp': '3/2/18, 10:19:51 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '14': {'fair': True,
#    'timeToDecide': Decimal('59.5173870325089'),
#    'timestamp': '3/1/18, 4:17:29 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '140': {'fair': True,
#    'timeToDecide': Decimal('3.11950302124023'),
#    'timestamp': '4/19/18, 4:15:40 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '142': {'fair': False,
#    'timeToDecide': Decimal('1.60577607154846'),
#    'timestamp': '3/9/18, 12:10:08 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '148': {'fair': True,
#    'timeToDecide': Decimal('73.9182509183884'),
#    'timestamp': '3/8/18, 4:40:15 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': True},
#   '156': {'fair': True,
#    'timeToDecide': Decimal('5.53868997097015'),
#    'timestamp': '3/1/18, 4:17:36 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '170': {'fair': True,
#    'timeToDecide': Decimal('4.71021807193756'),
#    'timestamp': '3/8/18, 8:41:15 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '173': {'fair': True,
#    'timeToDecide': Decimal('28.0110350847244'),
#    'timestamp': '4/19/18, 4:19:33 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '179': {'fair': True,
#    'timeToDecide': Decimal('2.81485199928284'),
#    'timestamp': '3/8/18, 4:40:18 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '183': {'fair': False,
#    'timeToDecide': Decimal('1.915403008461'),
#    'timestamp': '2/23/18, 2:06:55 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '187': {'fair': True,
#    'timeToDecide': Decimal('2.12038898468018'),
#    'timestamp': '3/1/18, 4:23:11 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '190': {'fair': True,
#    'timeToDecide': Decimal('17.8463790416718'),
#    'timestamp': '2/24/18, 8:09:22 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '194': {'fair': True,
#    'timeToDecide': Decimal('140.917258024216'),
#    'timestamp': '4/5/18, 4:21:57 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '198': {'fair': True,
#    'timeToDecide': Decimal('2.76792907714844'),
#    'timestamp': '3/8/18, 4:40:24 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '201': {'fair': False,
#    'timeToDecide': Decimal('1.37983095645905'),
#    'timestamp': '3/1/18, 4:17:31 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '202': {'fair': True,
#    'timeToDecide': Decimal('146.720826029778'),
#    'timestamp': '3/8/18, 4:35:17 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '205': {'fair': True,
#    'timeToDecide': Decimal('2.94774508476257'),
#    'timestamp': '4/19/18, 4:18:55 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '211': {'fair': False,
#    'timeToDecide': Decimal('2.6710159778595'),
#    'timestamp': '2/24/18, 8:09:25 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '219': {'fair': False,
#    'timeToDecide': Decimal('1.85136198997498'),
#    'timestamp': '2/23/18, 2:06:51 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '255': {'fair': False,
#    'timeToDecide': Decimal('1.92586600780487'),
#    'timestamp': '3/22/18, 12:54:18 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '265': {'fair': False,
#    'timeToDecide': Decimal('76.7663620710373'),
#    'timestamp': '3/1/18, 4:25:21 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedRace': False},
#   '276': {'fair': True,
#    'timeToDecide': Decimal('6.28761696815491'),
#    'timestamp': '2/24/18, 8:09:32 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '297': {'fair': True,
#    'timeToDecide': Decimal('2.61044001579285'),
#    'timestamp': '3/2/18, 10:20:11 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '299': {'fair': False,
#    'timeToDecide': Decimal('2.44340598583221'),
#    'timestamp': '2/22/18, 5:28:22 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '3': {'fair': False,
#    'timeToDecide': Decimal('2.54363703727722'),
#    'timestamp': '3/2/18, 10:19:55 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '30': {'fair': True,
#    'timeToDecide': Decimal('3.41142797470093'),
#    'timestamp': '2/22/18, 5:28:19 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '301': {'fair': True,
#    'timeToDecide': Decimal('89.9993300437927'),
#    'timestamp': '3/8/18, 4:39:01 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '304': {'fair': False,
#    'timeToDecide': Decimal('2.31448304653168'),
#    'timestamp': '4/19/18, 4:15:36 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '309': {'fair': False,
#    'timeToDecide': Decimal('2.27948403358459'),
#    'timestamp': '3/2/18, 10:20:13 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '321': {'fair': True,
#    'timeToDecide': Decimal('8.13165199756622'),
#    'timestamp': '3/8/18, 4:32:50 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '325': {'fair': False,
#    'timeToDecide': Decimal('29.3474930524826'),
#    'timestamp': '3/8/18, 4:32:42 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '336': {'fair': True,
#    'timeToDecide': Decimal('32.0935769081116'),
#    'timestamp': '2/23/18, 2:06:49 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '344': {'fair': False,
#    'timeToDecide': Decimal('3.00146889686584'),
#    'timestamp': '3/1/18, 4:23:14 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '347': {'fair': True,
#    'timeToDecide': Decimal('2.63258099555969'),
#    'timestamp': '3/8/18, 4:35:19 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '351': {'fair': True,
#    'timeToDecide': Decimal('95.5114779472351'),
#    'timestamp': '3/8/18, 4:37:24 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '353': {'fair': True,
#    'timeToDecide': Decimal('13.4975969791412'),
#    'timestamp': '3/8/18, 4:32:12 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '358': {'fair': True,
#    'timeToDecide': Decimal('2.03984999656677'),
#    'timestamp': '3/2/18, 10:19:57 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '360': {'fair': True,
#    'timeToDecide': Decimal('135.033736944199'),
#    'timestamp': '4/5/18, 4:16:29 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '361': {'fair': False,
#    'timeToDecide': Decimal('3.85030007362366'),
#    'timestamp': '3/1/18, 4:24:04 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '377': {'fair': True,
#    'timeToDecide': Decimal('58.6638289690018'),
#    'timestamp': '4/19/18, 4:45:30 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '378': {'fair': True,
#    'timeToDecide': Decimal('2.05028796195984'),
#    'timestamp': '2/23/18, 2:06:54 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '381': {'fair': True,
#    'timeToDecide': Decimal('13.6835119724274'),
#    'timestamp': '2/22/18, 5:28:15 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '390': {'fair': False,
#    'timeToDecide': Decimal('1.47441101074219'),
#    'timestamp': '3/2/18, 10:19:52 AM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '399': {'fair': True,
#    'timeToDecide': Decimal('2.17216598987579'),
#    'timestamp': '3/1/18, 4:17:42 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '401': {'fair': True,
#    'timeToDecide': Decimal('1472.16047596931'),
#    'timestamp': '4/19/18, 4:44:05 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': False,
#    'viewedIncome': True,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': True},
#   '417': {'fair': True,
#    'timeToDecide': Decimal('6.85417199134827'),
#    'timestamp': '3/8/18, 4:37:31 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '423': {'fair': True,
#    'timeToDecide': Decimal('5.73469400405884'),
#    'timestamp': '4/5/18, 4:14:14 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '427': {'fair': True,
#    'timeToDecide': Decimal('117.156170010567'),
#    'timestamp': '4/5/18, 4:18:27 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '43': {'fair': True,
#    'timeToDecide': Decimal('29.2736369371414'),
#    'timestamp': '3/8/18, 4:35:49 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '45': {'fair': True,
#    'timeToDecide': Decimal('3.0509740114212'),
#    'timestamp': '3/8/18, 4:40:21 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '46': {'fair': True,
#    'timeToDecide': Decimal('27.2040650844574'),
#    'timestamp': '4/23/18, 4:11:14 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': True,
#    'viewedRace': False},
#   '50': {'fair': False,
#    'timeToDecide': Decimal('43.2757159471512'),
#    'timestamp': '2/23/18, 2:07:39 PM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': True},
#   '67': {'fair': True,
#    'timeToDecide': Decimal('11.291522026062'),
#    'timestamp': '3/2/18, 10:20:08 AM Eastern Standard Time',
#    'viewedDemographics': True,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': False,
#    'viewedRace': False},
#   '69': {'fair': True,
#    'timeToDecide': Decimal('26.7099430561066'),
#    'timestamp': '3/1/18, 4:25:48 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedRace': False},
#   '72': {'fair': False,
#    'timeToDecide': Decimal('5.44064199924469'),
#    'timestamp': '4/19/18, 4:19:00 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '82': {'fair': True,
#    'timeToDecide': Decimal('7.97521996498108'),
#    'timestamp': '3/9/18, 12:10:06 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '84': {'fair': True,
#    'timeToDecide': Decimal('4.17357707023621'),
#    'timestamp': '4/19/18, 4:19:04 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '87': {'fair': True,
#    'timeToDecide': Decimal('38.6901580095291'),
#    'timestamp': '4/5/18, 4:19:36 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '9': {'fair': True,
#    'timeToDecide': Decimal('3.37890791893005'),
#    'timestamp': '3/4/18, 8:16:03 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '90': {'fair': True,
#    'timeToDecide': Decimal('26.6031370162964'),
#    'timestamp': '4/19/18, 4:44:32 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '98': {'fair': False,
#    'timeToDecide': Decimal('3.24134492874146'),
#    'timestamp': '3/1/18, 4:17:40 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   'userID': 'us-east-2:54d728ce-95b0-4c31-b301-c95e22143586'},
#  {'1': {'fair': False,
#    'timeToDecide': Decimal('1.61008810997009'),
#    'timestamp': '4/19/18, 5:18:00 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '106': {'fair': False,
#    'timeToDecide': Decimal('1.77350807189941'),
#    'timestamp': '4/19/18, 5:18:04 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '113': {'fair': True,
#    'timeToDecide': Decimal('1.52994704246521'),
#    'timestamp': '4/19/18, 5:17:44 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '119': {'fair': False,
#    'timeToDecide': Decimal('3.56702792644501'),
#    'timestamp': '4/8/18, 11:39:45 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '120': {'fair': True,
#    'timeToDecide': Decimal('6.33522403240204'),
#    'timestamp': '2/24/18, 7:52:26 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '127': {'fair': False,
#    'timeToDecide': Decimal('2.25275909900665'),
#    'timestamp': '4/19/18, 5:18:08 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '130': {'fair': False,
#    'timeToDecide': Decimal('11.7337530851364'),
#    'timestamp': '2/24/18, 8:09:05 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '141': {'fair': False,
#    'timeToDecide': Decimal('1.31419396400452'),
#    'timestamp': '4/19/18, 5:17:48 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '147': {'fair': True,
#    'timeToDecide': Decimal('3.28979396820068'),
#    'timestamp': '4/8/18, 11:39:24 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '170': {'fair': True,
#    'timeToDecide': Decimal('8.8486670255661'),
#    'timestamp': '4/19/18, 5:18:28 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': False,
#    'viewedRace': False},
#   '196': {'fair': False,
#    'timeToDecide': Decimal('16.0765450000763'),
#    'timestamp': '3/4/18, 4:35:56 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': True,
#    'viewedGraph': False,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '20': {'fair': True,
#    'timeToDecide': Decimal('2.90422105789185'),
#    'timestamp': '4/19/18, 5:17:51 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '203': {'fair': True,
#    'timeToDecide': Decimal('1.25972902774811'),
#    'timestamp': '4/19/18, 5:17:45 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '208': {'fair': True,
#    'timeToDecide': Decimal('1.69642806053162'),
#    'timestamp': '4/19/18, 5:17:42 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '223': {'fair': False,
#    'timeToDecide': Decimal('2.07138800621033'),
#    'timestamp': '4/8/18, 11:39:49 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '225': {'fair': False,
#    'timeToDecide': Decimal('14.1494089365005'),
#    'timestamp': '4/19/18, 5:18:42 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '232': {'fair': False,
#    'timeToDecide': Decimal('2.42389905452728'),
#    'timestamp': '4/19/18, 5:18:49 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '239': {'fair': True,
#    'timeToDecide': Decimal('3.17062795162201'),
#    'timestamp': '4/19/18, 5:18:14 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '251': {'fair': False,
#    'timeToDecide': Decimal('1.6434760093689'),
#    'timestamp': '4/8/18, 11:39:55 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '257': {'fair': False,
#    'timeToDecide': Decimal('1.66852295398712'),
#    'timestamp': '4/8/18, 11:39:26 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '269': {'fair': True,
#    'timeToDecide': Decimal('1.41359400749207'),
#    'timestamp': '4/19/18, 5:18:02 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '282': {'fair': False,
#    'timeToDecide': Decimal('1.51809799671173'),
#    'timestamp': '4/19/18, 5:17:40 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '288': {'fair': False,
#    'timeToDecide': Decimal('2.50765800476074'),
#    'timestamp': '4/8/18, 11:39:52 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '30': {'fair': True,
#    'timeToDecide': Decimal('1.78824400901794'),
#    'timestamp': '4/8/18, 11:39:54 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '300': {'fair': True,
#    'timeToDecide': Decimal('14.1967170238495'),
#    'timestamp': '4/6/18, 1:03:39 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': True,
#    'viewedGraph': False,
#    'viewedIncome': True,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': True},
#   '310': {'fair': False,
#    'timeToDecide': Decimal('1.72960305213928'),
#    'timestamp': '4/8/18, 11:39:42 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '314': {'fair': False,
#    'timeToDecide': Decimal('18.2191060781479'),
#    'timestamp': '4/6/18, 12:51:41 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '323': {'fair': False,
#    'timeToDecide': Decimal('7.13033497333527'),
#    'timestamp': '3/4/18, 4:24:20 PM Eastern Standard Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedRace': False},
#   '337': {'fair': True,
#    'timeToDecide': Decimal('3562.02050101757'),
#    'timestamp': '4/19/18, 5:17:37 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': True,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': False},
#   '340': {'fair': True,
#    'timeToDecide': Decimal('1.57863998413086'),
#    'timestamp': '4/19/18, 5:17:39 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '357': {'fair': False,
#    'timeToDecide': Decimal('2.18569993972778'),
#    'timestamp': '4/19/18, 5:18:11 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '375': {'fair': True,
#    'timeToDecide': Decimal('1.43908190727234'),
#    'timestamp': '4/19/18, 5:17:59 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '391': {'fair': False,
#    'timeToDecide': Decimal('2.2909129858017'),
#    'timestamp': '4/19/18, 5:18:06 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '4': {'fair': False,
#    'timeToDecide': Decimal('3.75848507881165'),
#    'timestamp': '3/19/18, 5:24:52 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '406': {'fair': True,
#    'timeToDecide': Decimal('1.71349096298218'),
#    'timestamp': '4/8/18, 11:39:40 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '410': {'fair': True,
#    'timeToDecide': Decimal('23.7185130119324'),
#    'timestamp': '4/8/18, 11:39:21 AM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': True,
#    'viewedName': True,
#    'viewedRace': True},
#   '427': {'fair': True,
#    'timeToDecide': Decimal('1.59263002872467'),
#    'timestamp': '4/19/18, 5:17:53 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '434': {'fair': True,
#    'timeToDecide': Decimal('1.92133104801178'),
#    'timestamp': '4/19/18, 5:17:57 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '47': {'fair': False,
#    'timeToDecide': Decimal('5.48870098590851'),
#    'timestamp': '4/19/18, 5:18:19 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '51': {'fair': True,
#    'timeToDecide': Decimal('47.1821810007095'),
#    'timestamp': '4/2/18, 4:59:54 PM Eastern Daylight Time',
#    'viewedDemographics': True,
#    'viewedEducation': True,
#    'viewedGraph': True,
#    'viewedIncome': True,
#    'viewedMap': False,
#    'viewedName': True,
#    'viewedRace': True},
#   '58': {'fair': True,
#    'timeToDecide': Decimal('1.58779108524323'),
#    'timestamp': '4/8/18, 11:39:47 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '6': {'fair': True,
#    'timeToDecide': Decimal('12.2339179515839'),
#    'timestamp': '4/8/18, 11:39:38 AM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': True,
#    'viewedName': False,
#    'viewedRace': False},
#   '85': {'fair': False,
#    'timeToDecide': Decimal('2.1606719493866'),
#    'timestamp': '4/19/18, 5:18:45 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '87': {'fair': False,
#    'timeToDecide': Decimal('2.8143550157547'),
#    'timestamp': '4/19/18, 5:17:55 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '94': {'fair': False,
#    'timeToDecide': Decimal('1.72743809223175'),
#    'timestamp': '4/19/18, 5:18:46 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   '96': {'fair': True,
#    'timeToDecide': Decimal('1.6362669467926'),
#    'timestamp': '4/19/18, 5:17:47 PM Eastern Daylight Time',
#    'viewedDemographics': False,
#    'viewedEducation': False,
#    'viewedGraph': False,
#    'viewedIncome': False,
#    'viewedMap': False,
#    'viewedName': False,
#    'viewedRace': False},
#   'userID': 'us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17'}]

# %%
def pandify(a):
    """Technical term :) Makes the response dictionary into a pandas DataFrame"""
    
    ids = []
    fair = []
    tds = []
    ts = []
    v_demo = []
    v_ed = []
    v_gra = []
    v_inc = []
    v_map = []
    v_name = []
    v_race = []
    user = []
    
    # we keep track of the recorrds per user because we don't know how many times they have responded in
    # in advance
    count = 0
    for user_responses in a:
        for dist_id in user_responses:
            if dist_id != "userID":
                response = user_responses[dist_id]

                ids.append(int(dist_id))
                fair.append(response.get('fair', None))
                tds.append(float(response.get('timeToDecide', -1)))
                ts.append(response.get('timestamp', None))
                v_demo.append(response.get('viewedDemographics', None))
                v_ed.append(response.get('viewedEducation', None))
                v_gra.append(response.get('viewedGraph', None))
                v_inc.append(response.get('viewedIncome', None))
                v_map.append(response.get('viewedMap', None))
                v_name.append(response.get('viewedName', None))
                v_race.append(response.get('viewedRace', None))
                count += 1
        user += [user_responses['userID']] * count  # Python magic appends array
        count = 0
    
    # now we build a DataFrame
    frame = pd.DataFrame({'distID': ids, 'userID': user, 'fair': fair, 'TD': tds, 'TS': ts, 'vDemo': v_demo, 'vEdu': v_ed, 'vGraph': v_gra,
                         'vInc': v_inc, 'vMap': v_map, 'vName': v_name, 'vRace': v_race})
    return frame

# %%
frame = pandify(items)
frame.head()
# Out:
#           TD                                         TS  distID  fair  \
# 0   1.319266  4/15/18, 1:31:23 PM Pacific Daylight Time     287  True
# 1   2.889119  4/15/18, 1:31:19 PM Pacific Daylight Time     202  True
# 2   2.431155  4/15/18, 1:31:21 PM Pacific Daylight Time      14  True
# 3  11.291522  3/2/18, 10:20:08 AM Eastern Standard Time      67  True
# 4  26.709943   3/1/18, 4:25:48 PM Eastern Standard Time      69  True
#
#                                            userID  vDemo   vEdu vGraph   vInc  \
# 0  us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False  False
# 1  us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False  False
# 2  us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False  False
# 3  us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True  False   True   True
# 4  us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False  False
#
#     vMap  vName  vRace
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False   None  False
# 4   True   None  False

# %% [markdown]
# #### Aggregated by User

# %% [markdown]
# This is probably not useful but gives a good idea of what we can do.

# %%
def aggregate_by_user(df):
    sliced = df[['distID', 'fair', 'userID']] # we only need these columns
    num_users = df.userID.nunique() # get the number of users
    
    matrix = np.empty((num_users, 441), dtype=int) # define an empty matrix filled with nans
    matrix.fill(np.nan)
    index = {} # keep track of which row users are stored in
    
    for _, row in sliced.iterrows():
        if row.userID not in index:
            index[row.userID] = len(index)
            
        if row.fair:
            matrix[index[row.userID], int(row.distID)] = 1
        else:
            matrix[index[row.userID], int(row.distID)] = 0
    
    new_ind = [None] * num_users # reverse the index
    for user in index:
        new_ind[index[user]] = user
        
    frame = pd.DataFrame(matrix, index=new_ind)
    return frame

aggregate_by_user(frame).head()
# Out:
#                                                                 0    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 1    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17                    0
#
#                                                                 2    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 3    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586                    0
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 4    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17                    0
#
#                                                                 5    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 6    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17                    1
#
#                                                                 7    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 8    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 9    \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586                    1
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                        ...           \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea         ...
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586         ...
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17         ...
#
#                                                                 431  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 432  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 433  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 434  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17                    1
#
#                                                                 435  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 436  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 437  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 438  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 439  \
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
#                                                                 440
# us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea -9223372036854775808
# us-east-2:54d728ce-95b0-4c31-b301-c95e22143586 -9223372036854775808
# us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17 -9223372036854775808
#
# [3 rows x 441 columns]

# %% [markdown]
# #### Load CSV

# %% [markdown]
# Next we load our compactness scores, which are provided as a CSV output of the Compactness notebook.

# %%
compactness = pd.read_csv('compactness.csv', index_col=0)
compactness.head()
# Out:
#    STATEFP CD115FP   PPopper      CHull    LongVar     LatVar    BClark  \
# 0        2      00 -1.539333  21.040088  21.047353  19.828083  6.750436
# 1       10      00  1.972069  -0.057290  -0.048865  -0.112271 -1.151813
# 2       30      00  1.385478   0.196834  -0.015619   1.308340 -0.801309
# 3       38      00  1.489508   0.056164  -0.037410   0.413603 -1.974687
# 4       46      00  2.016713   0.068255  -0.030917   0.820600 -1.139430
#
#        XSym      YSym
# 0 -0.942557 -3.028228
# 1 -0.249933  0.249403
# 2  1.093344  1.552939
# 3  2.013228  1.865749
# 4  1.306477  1.979569

# %% [markdown]
# #### Load SQL/JSON

# %% [markdown]
# FIPS codes are also stored in a JSON, taken from the Scripts directory of the app repository.

# %%
fips_map = {}
with open('states.json') as js_file:
    fips_map = json.load(js_file)

# %% [markdown]
# We load the SQL database from the app to match up internal IDs with geography. In the future I plan to separate this out to another script/JSON file.

# %%
conn = sqlite3.connect('districts.sql')
curs = conn.cursor()

mapping = {}

for row in curs.execute('''SELECT id, number, state FROM districts;'''):
    i, number, state = row
    mapping[str(number)+state] = int(i) # numberState -> id

# %%
def get_id(row):
    cd115 = row.CD115FP
    if cd115 == 'ZZ':
        return None
    return mapping.get(str(int(cd115))+fips_map[str(row.STATEFP)])

# %%
compactness['distID'] = compactness.apply(get_id, axis=1)

# %%
nc = compactness[pd.notnull(compactness['distID'])] # remove id-less districts
nc.distID = nc.distID.astype('int')
nc = nc.set_index('distID')

# %%
nc.describe()
# Out:
#           STATEFP     PPopper       CHull     LongVar      LatVar      BClark  \
# count  437.000000  437.000000  437.000000  437.000000  437.000000  437.000000
# mean    27.723112   -0.006508    0.000767    0.000768   -0.004671   -0.005415
# std     16.250723    0.984638    1.009112    1.009114    1.001898    1.001881
# min      1.000000   -1.783652   -0.061518   -0.048931   -0.221122   -1.996085
# 25%     12.000000   -0.743379   -0.060573   -0.048867   -0.210982   -0.703214
# 50%     27.000000   -0.212788   -0.056588   -0.048583   -0.170906   -0.069447
# 75%     42.000000    0.613698   -0.046462   -0.047757   -0.055731    0.593119
# max     72.000000    3.882557   21.040088   21.047353   19.828083    6.750436
#
#              XSym        YSym
# count  437.000000  437.000000
# mean     0.017098    0.019538
# std      0.980826    0.977276
# min     -3.101399   -3.036078
# 25%     -0.639026   -0.620420
# 50%      0.143546    0.137772
# 75%      0.764822    0.749830
# max      2.142786    2.113769

# %%
nc = nc.sort_index()
nc.head()
# Out:
#         STATEFP CD115FP   PPopper     CHull   LongVar    LatVar    BClark  \
# distID
# 0             6      40 -0.284821 -0.061426 -0.048927 -0.219651  0.055951
# 1             6      02 -0.563483 -0.026708 -0.048357  0.895210  0.473893
# 2             6      31 -1.359767 -0.061039 -0.048838 -0.219508  1.451142
# 3             6      10  0.595813 -0.058149 -0.048714 -0.175429  0.126529
# 4             6      09  0.749631 -0.059348 -0.048699 -0.193318 -0.512837
#
#             XSym      YSym
# distID
# 0      -0.765415 -0.861384
# 1      -0.318009  0.087526
# 2      -0.385799 -0.823153
# 3       0.072523 -0.061987
# 4       1.240484  0.693277

# %%
measures = ["PPopper", "CHull","LongVar", "LatVar", "BClark", "XSym", "YSym"]

for column in measures:
    nc[column] = scale(nc[column]) # scale measures

# %%
nc.describe()
# Out:
#           STATEFP       PPopper         CHull       LongVar        LatVar  \
# count  437.000000  4.370000e+02  4.370000e+02  4.370000e+02  4.370000e+02
# mean    27.723112  4.064890e-18  1.219467e-17 -4.064890e-18  4.064890e-18
# std     16.250723  1.001146e+00  1.001146e+00  1.001146e+00  1.001146e+00
# min      1.000000 -1.806939e+00 -6.179266e-02 -4.930655e-02 -2.162894e-01
# 25%     12.000000 -7.492258e-01 -6.085501e-02 -4.924315e-02 -2.061568e-01
# 50%     27.000000 -2.097389e-01 -5.690170e-02 -4.896102e-02 -1.661105e-01
# 75%     42.000000  6.306042e-01 -4.685594e-02 -4.814150e-02 -5.102252e-02
# max     72.000000  3.954267e+00  2.087323e+01  2.088040e+01  1.981787e+01
#
#              BClark          XSym          YSym
# count  4.370000e+02  4.370000e+02  4.370000e+02
# mean   1.219467e-17  2.032445e-17  2.845423e-17
# std    1.001146e+00  1.001146e+00  1.001146e+00
# min   -1.989210e+00 -3.183102e+00 -3.130251e+00
# 25%   -6.972874e-01 -6.697167e-01 -6.555893e-01
# 50%   -6.398526e-02  1.290678e-01  1.211223e-01
# 75%    5.980944e-01  7.632142e-01  7.481305e-01
# max    6.750896e+00  2.169726e+00  2.145384e+00

# %% [markdown]
# #### Aggregating Responses

# %%
summed = frame[["fair", "distID"]].groupby("distID").sum()
counts = frame[["fair", "distID"]].groupby("distID").count()

# %%
percents = summed.divide(counts)
percents.head()
# Out:
#         fair
# distID
# 1        0.0
# 3        0.0
# 4        0.0
# 6        1.0
# 9        1.0

# %%
combined = percents.join(nc, how="outer")

# %%
combined.head()
# Out:
#         fair  STATEFP CD115FP   PPopper     CHull   LongVar    LatVar  \
# distID
# 0        NaN        6      40 -0.282979 -0.061702 -0.049302 -0.214819
# 1        0.0        6      02 -0.566314 -0.027258 -0.048737  0.899205
# 2        NaN        6      31 -1.375948 -0.061318 -0.049215 -0.214676
# 3        0.0        6      10  0.612419 -0.058451 -0.049091 -0.170630
# 4        0.0        6      09  0.768815 -0.059640 -0.049077 -0.188506
#
#           BClark      XSym      YSym
# distID
# 0       0.061321 -0.798724 -0.902439
# 1       0.478956 -0.342049  0.069649
# 2       1.455489 -0.411244 -0.863274
# 3       0.131847  0.056573 -0.083516
# 4      -0.507050  1.248730  0.690196

# %%
fig = ff.create_scatterplotmatrix(combined[measures+["fair"]], height=800, width=800)
iplot(fig, filename='Combined Graph')

# %% [markdown]
# #### Classifier

# %%
svm_data = frame.join(nc, how="inner", on="distID")
svm_data
# Out:
#               TD                                          TS  distID   fair  \
# 0       1.319266   4/15/18, 1:31:23 PM Pacific Daylight Time     287   True
# 1       2.889119   4/15/18, 1:31:19 PM Pacific Daylight Time     202   True
# 8     146.720826    3/8/18, 4:35:17 PM Eastern Standard Time     202   True
# 2       2.431155   4/15/18, 1:31:21 PM Pacific Daylight Time      14   True
# 58     59.517387    3/1/18, 4:17:29 PM Eastern Standard Time      14   True
# 3      11.291522   3/2/18, 10:20:08 AM Eastern Standard Time      67   True
# 4      26.709943    3/1/18, 4:25:48 PM Eastern Standard Time      69   True
# 5       3.850300    3/1/18, 4:24:04 PM Eastern Standard Time     361  False
# 6     135.033737    4/5/18, 4:16:29 PM Eastern Daylight Time     360   True
# 7       8.131652    3/8/18, 4:32:50 PM Eastern Standard Time     321   True
# 9       1.379831    3/1/18, 4:17:31 PM Eastern Standard Time     201  False
# 10     29.347493    3/8/18, 4:32:42 PM Eastern Standard Time     325  False
# 11   1472.160476   4/19/18, 4:44:05 PM Eastern Daylight Time     401   True
# 12    262.761456    3/1/18, 4:23:08 PM Eastern Standard Time     128   True
# 13      2.947745   4/19/18, 4:18:55 PM Eastern Daylight Time     205   True
# 14      5.440642   4/19/18, 4:19:00 PM Eastern Daylight Time      72  False
# 15      3.411428   2/22/18, 5:28:19 PM Eastern Standard Time      30   True
# 93      1.788244   4/8/18, 11:39:54 AM Eastern Daylight Time      30   True
# 16      4.710218    3/8/18, 8:41:15 AM Eastern Standard Time     170   True
# 96      8.848667   4/19/18, 5:18:28 PM Eastern Daylight Time     170   True
# 17     28.011035   4/19/18, 4:19:33 PM Eastern Daylight Time     173   True
# 18      2.610440   3/2/18, 10:20:11 AM Eastern Standard Time     297   True
# 19      2.443406   2/22/18, 5:28:22 PM Eastern Standard Time     299  False
# 20      2.671016   2/24/18, 8:09:25 PM Eastern Standard Time     211  False
# 21      1.925866  3/22/18, 12:54:18 PM Eastern Daylight Time     255  False
# 22      2.050288   2/23/18, 2:06:54 PM Eastern Standard Time     378   True
# 23      1.382912    3/1/18, 4:17:44 PM Eastern Standard Time     136   True
# 24      2.814852    3/8/18, 4:40:18 PM Eastern Standard Time     179   True
# 25     58.663829   4/19/18, 4:45:30 PM Eastern Daylight Time     377   True
# 26     32.093577   2/23/18, 2:06:49 PM Eastern Standard Time     336   True
# ..           ...                                         ...     ...    ...
# 81      2.071388   4/8/18, 11:39:49 AM Eastern Daylight Time     223  False
# 82      2.252759   4/19/18, 5:18:08 PM Eastern Daylight Time     127  False
# 83     12.233918   4/8/18, 11:39:38 AM Eastern Daylight Time       6   True
# 84      1.259729   4/19/18, 5:17:45 PM Eastern Daylight Time     203   True
# 85      1.413594   4/19/18, 5:18:02 PM Eastern Daylight Time     269   True
# 86     14.149409   4/19/18, 5:18:42 PM Eastern Daylight Time     225  False
# 88      1.713491   4/8/18, 11:39:40 AM Eastern Daylight Time     406   True
# 89      1.696428   4/19/18, 5:17:42 PM Eastern Daylight Time     208   True
# 91      1.727438   4/19/18, 5:18:46 PM Eastern Daylight Time      94  False
# 92     47.182181    4/2/18, 4:59:54 PM Eastern Daylight Time      51   True
# 94      1.636267   4/19/18, 5:17:47 PM Eastern Daylight Time      96   True
# 95      1.587791   4/8/18, 11:39:47 AM Eastern Daylight Time      58   True
# 97      2.290913   4/19/18, 5:18:06 PM Eastern Daylight Time     391  False
# 98     11.733753   2/24/18, 8:09:05 PM Eastern Standard Time     130  False
# 99     16.076545    3/4/18, 4:35:56 PM Eastern Standard Time     196  False
# 100     1.643476   4/8/18, 11:39:55 AM Eastern Daylight Time     251  False
# 101     1.729603   4/8/18, 11:39:42 AM Eastern Daylight Time     310  False
# 102     1.439082   4/19/18, 5:17:59 PM Eastern Daylight Time     375   True
# 103     2.423899   4/19/18, 5:18:49 PM Eastern Daylight Time     232  False
# 104     1.668523   4/8/18, 11:39:26 AM Eastern Daylight Time     257  False
# 105    23.718513   4/8/18, 11:39:21 AM Eastern Daylight Time     410   True
# 106     1.529947   4/19/18, 5:17:44 PM Eastern Daylight Time     113   True
# 107    18.219106   4/6/18, 12:51:41 AM Eastern Daylight Time     314  False
# 108     1.921331   4/19/18, 5:17:57 PM Eastern Daylight Time     434   True
# 109     2.185700   4/19/18, 5:18:11 PM Eastern Daylight Time     357  False
# 110     3.170628   4/19/18, 5:18:14 PM Eastern Daylight Time     239   True
# 111  3562.020501   4/19/18, 5:17:37 PM Eastern Daylight Time     337   True
# 112     3.567028   4/8/18, 11:39:45 AM Eastern Daylight Time     119  False
# 113     2.160672   4/19/18, 5:18:45 PM Eastern Daylight Time      85  False
# 114     2.904221   4/19/18, 5:17:51 PM Eastern Daylight Time      20   True
#
#                                              userID  vDemo   vEdu vGraph  \
# 0    us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False
# 1    us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False
# 8    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True   True   True
# 2    us-east-2:f8d3b730-1f6a-4141-acb6-8c689e1d2aea  False  False  False
# 58   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 3    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True  False   True
# 4    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 5    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 6    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True   True   True
# 7    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 9    us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 10   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 11   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True   True  False
# 12   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True   True   True
# 13   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 14   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 15   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 93   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 16   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 96   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 17   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586   True   True   True
# 18   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 19   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 20   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 21   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 22   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 23   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 24   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# 25   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False   True   True
# 26   us-east-2:54d728ce-95b0-4c31-b301-c95e22143586  False  False  False
# ..                                              ...    ...    ...    ...
# 81   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 82   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 83   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 84   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 85   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 86   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 88   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 89   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 91   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 92   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17   True   True   True
# 94   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 95   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 97   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 98   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 99   us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False   True  False
# 100  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 101  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 102  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 103  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 104  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 105  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17   True   True   True
# 106  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 107  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 108  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 109  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 110  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 111  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False   True
# 112  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 113  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
# 114  us-east-2:79ba0bfa-b183-4433-8992-caaf4a7b0d17  False  False  False
#
#       vInc   vMap    ...     vRace STATEFP  CD115FP   PPopper     CHull  \
# 0    False  False    ...     False       6       30 -0.512832 -0.061538
# 1    False  False    ...     False      29       07  1.591517 -0.050996
# 8     True   True    ...      True      29       07  1.591517 -0.050996
# 2    False  False    ...     False      12       02 -0.652593 -0.035245
# 58   False  False    ...     False      12       02 -0.652593 -0.035245
# 3     True  False    ...     False      22       03  0.445117 -0.047209
# 4    False   True    ...     False      42       04  0.928912 -0.059225
# 5    False  False    ...     False      26       14 -1.277614 -0.060966
# 6     True   True    ...      True      26       01  0.684369  0.044162
# 7    False  False    ...     False      48       21 -0.521590 -0.051942
# 9    False  False    ...     False      49       02  0.923129  0.009664
# 10   False  False    ...     False      29       05 -0.522466 -0.056725
# 11    True  False    ...      True      15       02 -1.537477  0.133175
# 12    True   True    ...      True      51       04 -0.428188 -0.054854
# 13   False  False    ...     False      40       04 -0.013260 -0.044258
# 14   False  False    ...     False      18       05  0.754373 -0.058194
# 15   False  False    ...     False      48       16  2.414102 -0.060835
# 93   False  False    ...     False      48       16  2.414102 -0.060835
# 16   False  False    ...     False       6       13  0.834046 -0.061594
# 96   False   True    ...     False       6       13  0.834046 -0.061594
# 17    True   True    ...      True       6       33 -0.527605 -0.060717
# 18   False  False    ...     False      42       03 -0.254893 -0.051403
# 19   False  False    ...     False      13       04  0.101316 -0.060983
# 20   False  False    ...     False      39       08  0.213097 -0.056052
# 21   False  False    ...     False      48       32 -1.041282 -0.061394
# 22   False  False    ...     False      17       01 -1.082734 -0.061211
# 23   False  False    ...     False      36       27  0.356611 -0.051280
# 24   False  False    ...     False      48       23 -0.370111  0.041185
# 25    True   True    ...      True      18       07  2.130126 -0.061350
# 26   False  False    ...     False      29       01  0.140338 -0.061361
# ..     ...    ...    ...       ...     ...      ...       ...       ...
# 81   False  False    ...     False      17       13 -0.556900 -0.046745
# 82   False  False    ...     False      51       05 -0.849741 -0.040060
# 83   False   True    ...     False      25       01  0.300848 -0.057022
# 84   False  False    ...     False      29       02 -0.426143 -0.060928
# 85   False  False    ...     False      32       01  2.550719 -0.061661
# 86   False   True    ...     False      36       18  0.388259 -0.058929
# 88   False  False    ...     False      29       08  0.697757 -0.027415
# 89   False  False    ...     False      39       02 -0.204042 -0.056127
# 91   False  False    ...     False      55       03 -0.692885 -0.031717
# 92    True  False    ...      True      13       07  0.046854 -0.061098
# 94   False  False    ...     False      24       07 -1.349216 -0.060527
# 95   False  False    ...     False      31       03  0.656997  0.059726
# 97   False  False    ...     False       6       25 -0.271154 -0.058497
# 98   False  False    ...     False      53       10 -0.170706 -0.059851
# 99    True   True    ...     False      48       07 -0.961006 -0.061445
# 100  False  False    ...     False      42       16 -1.080037 -0.059390
# 101  False  False    ...     False       9       05 -0.159248 -0.059284
# 102  False  False    ...     False      12       06  0.771236 -0.057371
# 103  False  False    ...     False       6       42 -1.154750 -0.059801
# 104  False  False    ...     False       1       01 -0.748537 -0.049196
# 105   True   True    ...      True      39       14  0.805302 -0.055943
# 106  False  False    ...     False      48       02 -1.461933 -0.060816
# 107  False  False    ...     False      23       01 -0.694573 -0.049016
# 108  False  False    ...     False      12       07  0.967183 -0.061140
# 109  False  False    ...     False      53       05  1.406076 -0.031367
# 110  False  False    ...     False      18       01  2.582334 -0.059463
# 111  False   True    ...     False      37       09 -0.635848 -0.053559
# 112  False  False    ...     False      42       18 -0.690568 -0.057318
# 113  False  False    ...     False      24       08 -1.411358 -0.059496
# 114  False  False    ...     False      47       03 -1.117451 -0.051399
#
#       LongVar    LatVar    BClark      XSym      YSym
# 0   -0.049276 -0.213899  0.558456  0.134853 -0.567393
# 1   -0.048240 -0.091555 -0.522172 -0.100078  1.132879
# 8   -0.048240 -0.091555 -0.522172 -0.100078  1.132879
# 2   -0.045754 -0.025905  1.227404 -0.703647 -0.106784
# 58  -0.045754 -0.025905  1.227404 -0.703647 -0.106784
# 3   -0.046682 -0.139290  0.373501  0.429078  1.105487
# 4   -0.048973 -0.188924 -0.183534 -0.844885  1.247109
# 5   -0.049248 -0.210069  0.702827 -1.973225 -2.022372
# 6   -0.039439  0.314713  0.315356 -0.948481 -0.733140
# 7   -0.047899 -0.158513 -0.049929  0.724970  0.920856
# 9   -0.046122  1.154329 -0.649882  0.825133 -0.306554
# 10  -0.048659 -0.192130  0.832197  0.113814 -0.159304
# 11   0.022707  2.266292  3.269857 -3.183102 -3.130251
# 12  -0.048804 -0.135833 -0.907156  0.588748 -0.432573
# 13  -0.047523 -0.002761 -0.679991  0.905655  0.670262
# 14  -0.048990 -0.161931 -0.439578  0.339573 -0.133475
# 15  -0.049188 -0.206755 -0.194042  0.977810  1.217975
# 93  -0.049188 -0.206755 -0.194042  0.977810  1.217975
# 16  -0.049295 -0.212688 -0.943491  0.073240  0.132037
# 96  -0.049295 -0.212688 -0.943491  0.073240  0.132037
# 17  -0.049241 -0.205246 -0.386461 -2.183096 -0.413441
# 18  -0.048943 -0.007927  0.323859 -0.433355 -0.664190
# 19  -0.049239 -0.203355 -1.078326  0.257509  0.298870
# 20  -0.049021 -0.117611  0.411773  0.655001 -1.132083
# 21  -0.049275 -0.212753  0.634197  0.301502  0.065118
# 22  -0.049265 -0.207759  1.230059 -2.348431 -1.358740
# 23  -0.048340 -0.164952 -0.323436  0.494166  0.621948
# 24  -0.032414  0.267993  0.307960 -0.797421 -0.176030
# 25  -0.049264 -0.211053 -0.945986  1.548351  1.947558
# 26  -0.049292 -0.211485 -1.013202  0.763377  0.974989
# ..        ...       ...       ...       ...       ...
# 81  -0.048316 -0.060366  2.220542 -2.382862 -1.577119
# 82  -0.047874  0.142639  0.610808 -0.806326 -0.053333
# 83  -0.048862 -0.184355  1.063757  0.487549 -0.295725
# 84  -0.049245 -0.205882 -0.865201  0.351465  0.758644
# 85  -0.049285 -0.215083  0.055775  1.647536  1.870272
# 86  -0.048937 -0.192776 -0.573212  0.598438  0.617040
# 88  -0.046609  0.279715 -1.132988  0.782276  1.542426
# 89  -0.048346 -0.173928 -0.182135  1.100910  1.006558
# 91  -0.047335  0.151745  0.378801 -1.242285 -1.345187
# 92  -0.049265 -0.205756 -0.757165  0.754833  0.232821
# 94  -0.049206 -0.205578  1.232590 -0.871986 -0.935094
# 95  -0.031032  0.632253  0.022532  1.247978  0.695971
# 97  -0.048952 -0.190432  1.090087  0.017947  0.679773
# 98  -0.049047 -0.198776 -0.053148  0.738853  0.426657
# 99  -0.049277 -0.211571 -0.168349 -1.361703 -0.772697
# 100 -0.049121 -0.189693  0.012308 -0.311163 -0.655589
# 101 -0.049180 -0.193353  0.171891  1.303259 -0.018042
# 102 -0.049142 -0.078429 -0.643192  0.242311  0.895043
# 103 -0.049171 -0.197114  0.506453 -0.746866 -0.032772
# 104 -0.048852 -0.074785  0.281245  0.253768 -0.895680
# 105 -0.048834 -0.182634 -1.075084  1.342628  0.732829
# 106 -0.049238 -0.207785  0.302262 -1.166921 -0.928668
# 107 -0.048401 -0.111547  0.291148 -1.283869 -0.670854
# 108 -0.049261 -0.204800 -1.207844  1.449199  1.097990
# 109 -0.047879  0.304731 -0.176886  1.355318  1.266105
# 110 -0.049090 -0.190446 -0.837347  1.359883  0.793781
# 111 -0.047759 -0.177473  1.859132 -1.167873 -1.007607
# 112 -0.048961 -0.189843  1.705693  0.562752 -0.597865
# 113 -0.049217 -0.179216  0.564698 -1.939115  0.147133
# 114 -0.048777 -0.030618  0.332250  0.405183 -0.235204
#
# [115 rows x 21 columns]

# %%
mask = np.random.rand(len(svm_data)) < 0.8
train = svm_data[mask]
validation = svm_data[~mask]

# %%
train_x, train_y = train[['PPopper', 'CHull', 'LongVar', 'LatVar', 'BClark', 'XSym', 'YSym']], train['fair']
valid_x, valid_y = validation[['PPopper', 'CHull', 'LongVar', 'LatVar', 'BClark', 'XSym', 'YSym']], validation['fair']

# %%
classifier = svm.SVC()
classifier.fit(train_x, train_y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
classifier.score(valid_x, valid_y)
# Out:
# 0.68000000000000005

# %% [markdown]
# Looks like this is just chance... more data might make this better.
